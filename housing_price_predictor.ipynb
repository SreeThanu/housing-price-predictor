# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Running cells with 'project-env (Python 3.12.4)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n project-env ipykernel --update-deps --force-reinstall'

# %%
data = pd.read_csv("/Users/sreethanubhuvaneshgk/Desktop/ml_projects/datasets/housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['median_house_value'], axis = 1)
y  = data['median_house_value']

# %%
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size = 0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((16346, 9), (4087, 9), (16346,), (4087,))

# %%
train_data = x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11612    -118.04     33.80                33.0       2685.0           466.0
# 6250     -117.98     34.04                34.0       2547.0           537.0
# 8038     -118.15     33.84                29.0       2448.0           354.0
# 12884    -121.34     38.66                16.0       3154.0           860.0
# 8598     -118.36     33.88                31.0       2518.0           543.0
# ...          ...       ...                 ...          ...             ...
# 3690     -118.36     34.22                37.0       1512.0           348.0
# 866      -122.04     37.57                12.0       5719.0          1064.0
# 9411     -122.51     37.87                21.0       3904.0           980.0
# 376      -122.16     37.75                40.0       1227.0           294.0
# 7382     -118.25     33.97                36.0       1026.0           294.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# #we can see from the above graphs that the graphs for the total rooms, total bedrooms, population, households are skewed and not in the form of gaussian bell curves
# #Hence we that the log of the current values of them so that we get the desired gaussian bell curve

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# #now what we want to accomplish is to take a heat map of the train_data.corr() function but this is currently not possilbe as the value for the column ocean proximity is in string value so we have to change it to integer value

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7272
# INLAND        5168
# NEAR OCEAN    2085
# NEAR BAY      1817
# ISLAND           4
# Name: count, dtype: int64

# %% [markdown]
# performing one hot encoding on the ocean proximity column

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity))
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11612    -118.04     33.80                33.0     7.895808        6.146329
# 6250     -117.98     34.04                34.0     7.843064        6.287859
# 8038     -118.15     33.84                29.0     7.803435        5.872118
# 12884    -121.34     38.66                16.0     8.056744        6.758095
# 8598     -118.36     33.88                31.0     7.831617        6.298949
# ...          ...       ...                 ...          ...             ...
# 3690     -118.36     34.22                37.0     7.321850        5.855072
# 866      -122.04     37.57                12.0     8.651724        6.970730
# 9411     -122.51     37.87                21.0     8.270013        6.888572
# 376      -122.16     37.75                40.0     7.113142        5.686975
# 7382     -118.25     33.97                36.0     6.934397        5.686975
#
# ...

# %%
train_data = train_data.drop('ocean_proximity', axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11612    -118.04     33.80                33.0     7.895808        6.146329
# 6250     -117.98     34.04                34.0     7.843064        6.287859
# 8038     -118.15     33.84                29.0     7.803435        5.872118
# 12884    -121.34     38.66                16.0     8.056744        6.758095
# 8598     -118.36     33.88                31.0     7.831617        6.298949
# ...          ...       ...                 ...          ...             ...
# 3690     -118.36     34.22                37.0     7.321850        5.855072
# 866      -122.04     37.57                12.0     8.651724        6.970730
# 9411     -122.51     37.87                21.0     8.270013        6.888572
# 376      -122.16     37.75                40.0     7.113142        5.686975
# 7382     -118.25     33.97                36.0     6.934397        5.686975
#
# ...

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924343           -0.105107     0.032193
# latitude            -0.924343  1.000000            0.008580    -0.034957
# housing_median_age  -0.105107  0.008580            1.000000    -0.317354
# total_rooms          0.032193 -0.034957           -0.317354     1.000000
# total_bedrooms       0.063439 -0.071060           -0.276255     0.945839
# population           0.114002 -0.140806           -0.244154     0.862471
# households           0.059151 -0.091668           -0.244469     0.931247
# median_income       -0.013592 -0.081594           -0.115246     0.206189
# median_house_value  -0.039179 -0.149649            0.105440     0.162098
# <1H OCEAN            0.321522 -0.448476            0.047038     0.023620
# INLAND              -0.055446  0.352309           -0.236064    -0.015393
# ISLAND               0.009501 -0.016670            0.014154    -0.005602
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = 'latitude', y = 'longitude', data = train_data, hue = 'median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train_data.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
x_train, y_train = train_data.drop(['median_house_value'], axis = 1), train_data['median_house_value']

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity))
test_data = test_data.drop('ocean_proximity', axis = 1) 

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis = 1), test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9718     -121.77     36.87                37.0     6.052089        4.189655
# 10052    -121.04     39.19                17.0     6.753438        5.123964
# 18597    -122.08     37.08                35.0     7.340836        5.697093
# 7322     -118.17     33.98                27.0     7.534763        6.322565
# 19412    -121.01     37.74                14.0     7.770223        5.697093
# ...          ...       ...                 ...          ...             ...
# 15724    -122.44     37.78                52.0     8.163656        6.674561
# 10395    -117.67     33.54                15.0     7.793174        6.077642
# 11033    -117.81     33.79                23.0     8.043984        6.415097
# 92       -122.28     37.80                52.0     4.574711        3.465736
# 15259    -117.27     33.03                25.0     7.488853        5.743003
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_train_s = scalar.fit_transform(x_train)
x_test_s = scalar.transform(x_test)

# %% [markdown]
# USING RANDOM FOREST REGRESSOR WITHOUT HYPER PARAMETER TUNING

# %%
from sklearn.ensemble import RandomForestRegressor
rfg = RandomForestRegressor()
rfg.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
rfg.score(x_test_s,y_test)
# Out:
# 0.8165452298217306

# %% [markdown]
# USING RANDOM FOREST REGRESSOR WITH HYPER PARAMETER TUNING (GRID SEARCH CROSS VALIDATION)

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()

parameter_grid = {
    "n_estimators":[100, 200, 300],
    "min_samples_split": [2, 4]
}

grid_search = GridSearchCV(forest, parameter_grid, cv = 5, scoring = "neg_mean_squared_error", return_train_score = True)

grid_search.fit(x_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %%
grid_search.best_estimator_.score(x_test_s, y_test)
# Out:
# 0.8180899331790494
